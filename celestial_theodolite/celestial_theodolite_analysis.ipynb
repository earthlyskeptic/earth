# %% [markdown]
# # Analysis of Celestial Theodolite Experiment
# #### Earthly Skeptic (earthlyskeptic@gmail.com, X/@earthlyskeptick)
#
# Observations presented by "flat Earthers" invariably debunk them. Here, we present an example of such a situation—the _celestial theodolite_ experiment. While the observations in this experiment are valid, flat Earthers brought out small discrepancies using flawed reasoning, which appear to show that a flat Earth model is a slightly better fit to the data. However, a deeper analysis of the entire dataset not only produces clean globe signatures, but the dataset screams "globe"! Notably, we see clear signatures of Earth's daily rotation **(15.04°/hour)** and yearly revolution **(3m:56s/day)** in the data, which confirms the globe and the heliocentric model.
#
# In this experiment, an observer records the time at which a nearby mountain peak occults a certain star. This observation is repeated for various stars on multiple dates and from different peaks. It turns out the observations were fine but the flat Earthers' analysis was flawed.
#
# #### Result 1: For a given peak and date, occultation time of a star varies linearly as the star's right ascension, with a reciprocal slope of 15.04°/hour
#
# A plot of occultation time (hours) vs. the (catalogued) right ascension (°) should give a straight line for each peak-date pair. The reciprocal of the slope of each line should nearly equal Earth's rotation rate of 15.04°/hour. We observe this consistently throughout the dataset (**Fig. 1**).
#
# ![Plot of star occultation time vs. cataloged right ascension for each peak-date pair.](right_ascension.svg)
#
# **Fig. 1.** Plot of star occultation time vs. cataloged right ascension for each peak-date pair, showing a clear signature of Earth's daily rotation, **(15.04°/hour)**.
#
# #### Result 2: For a given peak and star, occultation time drifts linearly with observation date, with a slope of 3m:56s/day
#
# A plot of occultation time (hours) vs. date should give a straight line for each peak-star pair. The slope of each line should nearly equal 3m:56s/day. This number is the daily stellar drift due to Earth's orbit around the Sun, and equals the ratio of the two fundamental periods of Earth—its rotation period (1 day) and its revolution period (1 year). We observe this almost exactly for all stars that were observed on multiple dates (**Fig. 2**).
#
# ![Plot of occultation time vs. date for each peak-star pair.](daily_drift.svg)
#
# **Fig. 2.** Plot of occultation time vs. date for each peak-star pair measured on multiple days, showing a clear signature of Earth's yearly heliocentric orbit, **(3m:56s/day)**.
#
# #### Result 3a: For a given observation site, all stars occulted by a peak have the same declination
#
# For a given observer location and peak, all obscured stars have very nearly the same declination. We see this clearly throughout the dataset (**Fig. 3**).
#
# #### Result 3b: For a given observation site, the declination of the stars occulted by each peak can be calculated using globe geometry
#
# The (nearly identical) declination of the stars occulted by a peak as seen from a given observation site can be predicted by using globe geometry. This prediction uses the observer's and peak's coordinates to compute the elevation and azimuth of the peak from the observer, and then computes the declination from these angles (see model below). We see that this prediction closely matches the cataloged declination throughout the dataset (**Fig. 4**).
#
# #### Result 3c: For a given observation site, we can use known data (declinations of the stars occulted by different peaks, observer elevation and peak elevations) to estimate the Earth's radius
#
# For a given observation site, the relationship between the star declination and peak height uses Earth's radius as a parameter. Thus, this relationship can be used to estimate the radius by fitting a radius that minimizes the sum-of-squared residuals. **Fig. 5** shows that this estimation gives a radius of 3,911 mile, which is impressively within 1.25% of the known average radius of 3,959 mile.
#
# ![Plot of declination vs. right ascension for each peak.](declination.svg)
#
# **Fig. 3.** Plot of declination vs. right ascension for each peak, showing that from a given observation site, all stars occulted by a peak have the same declination.
#
# ![Plot of predicted declination (from a globe model) vs. cataloged declination for each peak.](declination_correlation.svg)
#
# **Fig. 4.** Plot of predicted declination (from a globe model) vs. cataloged declination for each peak, showing that the globe model can be used to precisely predict the declination of the stars occulted by that peak.
#
# ![Estimating Earth's radius from dataset.](estimated_radius.svg)
#
# **Fig. 5.** Plot of sum-of-squared residuals as a function of the radius parameter $R$ in the declination model, assuming an error of 0.25° or 25 arcminutes. The estimated radius is 3,911 mile, which is impressively within 1.25% of the known average radius of 3,959 mile.
#
# ### Equations for predicting declination of stars occulted by a peak for a given observer location
#
# For an observer located at coordinates (latitude $\phi_{ob}$, longitude $\lambda_{ob}$) and a peak located at (latitude $\phi_{pk}$, longitude $\lambda_{pk}$), the central angle $\theta$ between the observer and the peak is given by:
#
# $$\boxed{
# \cos \theta = \sin(\phi_{ob}) \sin(\phi_{pk}) +
# \cos(\phi_{ob}) \cos(\phi_{pk}) \cos(\lambda_{pk} - \lambda_{ob})
# }
# $$
#
# A straightforward way of deriving $\theta$ is to use an Earth-centric, Earth-fixed reference frame, take the dot product of the observer's position vector $\mathbf{r_{ob}}$ and the peak's position vector $\mathbf{r_{pk}}$ and divide the dot product $\mathbf{r_{ob} \cdot r_{pk}}$ by $(R+h) (R+H)$, where $R$ is Earth's radius, $h$ is the peak altitude and $H$ is the observer altitude (both measured above sea level).
#
# The elevation angle of the peak as seen by the observer, $e_{pk}$, is given by:
#
# $$\boxed{
# \sin (e_{pk}) =
# \frac{(R+h) \cos \theta - (R + H)}
# {\sqrt{(R+h)^2 + (R+H)^2 - 2 (R+h) (R+H) \cos \theta}}
# }
# $$
#
# This relationship can be derived by realizing that the altitude of the peak above the observer's horizontal is $(R+h) \cos \theta - R$ and the sine of $e_{pk}$ is the ratio of this altitude to the line-of-sight distance between the observer and the peak. The line of sight is given by the vector $\mathbf{v_{los}} = \mathbf{r_{pk} - r_{ob}}$, and its magnitude can be evaluated by $|\mathbf{v_{los}}| = \sqrt{\mathbf{v_{los} \cdot v_{los}}}$.
#
# To get the azimuth of the peak from the observer, we define local east-north-up (ENU) unit vectors $\mathbf{\hat{e}}$, $\mathbf{\hat{n}}$ and $\mathbf{\hat{u}}$ at the observer, which are mutually orthogonal:
#
# $$
# \mathbf{\hat e} =
# \begin{bmatrix}
# -\sin \lambda_{ob}\\
# \cos \lambda_{ob}\\
# 0
# \end{bmatrix}
# \qquad
# \mathbf{\hat n} =
# \begin{bmatrix}
# -\sin \phi_{ob} \cos \lambda_{ob}\\
# -\sin \phi_{ob} \sin \lambda_{ob}\\
# \cos \phi_{ob}
# \end{bmatrix}
# \qquad
# \mathbf{\hat u} =
# \begin{bmatrix}
# \cos \phi_{ob} \cos \lambda_{ob}\\
# \cos \phi_{ob} \sin \lambda_{ob}\\
# \sin \phi_{ob}
# \end{bmatrix}
# $$
#
# On projecting the unit line-of-sight vector $\mathbf{v_{los}}/|\mathbf{v_{los}}|$ to the unit vectors along north ($\mathbf{\hat n}$) and east ($\mathbf{\hat e}$) and taking the arctangent of their ratio, we get the azimuth of the peak. $A_{pk}$:
#
# $$
# A_{pk} = \tan^{-1}
# \left (
# \frac
# {\mathbf{v_{los}}/|\mathbf{v_{los}}| \cdot \mathbf{\hat e}}
# {\mathbf{v_{los}}/|\mathbf{v_{los}}| \cdot \mathbf{\hat n}}
# \right )
# $$
#
# On simplifying and determining the quadrant appropriately, we get:
#
# $$
# \boxed{
# A_{pk} = \tan^{-1}
# \left (
# \frac
# {\sin(\lambda_{pk}-\lambda_{ob}) \cos\phi_{pk}}
# {\cos\phi_{ob} \sin\phi_{pk} -
# \sin\phi_{ob}\,\cos\phi_{pk}\,\cos(\lambda_{pk}-\lambda_{ob})}
# \right )
# }
# $$
#
# The line-of-sight unit vector in ENU coordinates is:
#
# $$
# \mathbf{\hat s}_{\rm ENU} =
# \begin{bmatrix}
# \cos e_{\rm pk}\,\sin A_{\rm pk} \\
# \cos e_{\rm pk}\,\cos A_{\rm pk} \\
# \sin e_{\rm pk}
# \end{bmatrix}
# $$
#
# This can be transformed to the ECEF system to get the declination $\delta$ of the star:
#
# $$
# \boxed{
# \sin\delta =
# \sin\phi_{ob}\,\sin e_{\rm pk} +
# \cos\phi_{ob}\,\cos e_{\rm pk}\,\cos A_{\rm pk}
# }
# $$

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
import scipy.optimize as opt

pd.set_option('display.max_columns', None)

# %config InlineBackend.figure_format='svg'
# %matplotlib inline


def get_color(key):
    match key:
        case 0:
            return '#D32F2F'  # strong red
        case 1:
            return '#1976D2'  # strong blue
        case 2:
            return '#388E3C'  # strong green
        case 3:
            return '#F57C00'  # vivid orange
        case 4:
            return '#7B1FA2'  # saturated purple
        case 5:
            return '#0097A7'  # cyan-teal
        case 6:
            return '#FF00FF'  # magenta/shocking pink
        case 7:
            return '#5D4037'  # dark brown
        case 8:
            return '#AFB42B'  # yellow-green
        case 9:
            return '#0288D1'  # sky blue
        case 10:
            return '#E64A19'  # red-orange
        case 11:
            return '#512DA8'  # deep indigo
        case 12:
            return '#FBC02D'  # bright gold/yellow
        case 13:
            return '#00796B'  # blue-green
        case 14:
            return '#8D6E63'  # light brown/taupe
        case 15:
            return '#303F9F'  # blue-indigo
        case 16:
            return '#C0CA33'  # lime (high luminance)
        case 17:
            return '#AD1457'  # deep raspberry
        case 18:
            return '#455A64'  # slate blue-gray
        case 19:
            return '#000000'  # black
        case _:
            return '#9E9E9E'  # neutral gray fallback


def min_sec(minutes):
    sign = np.sign(minutes)  # preserve sign
    minutes = np.abs(minutes)
    minutes_frac = np.mod(minutes, 1)
    seconds = minutes_frac * 60
    minutes_int = minutes - minutes_frac
    minutes_int *= sign
    return f"{minutes_int:.0f}m:{seconds:.0f}s"

# %%
# Import data
sheet_id = "1EFb-lSvuEHGp-Jo9zXLhFq52R2fWc571VjPvC2vagTc"
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=xlsx"
df = pd.read_excel(url,
                   index_col=[0, 10, 16],
                   header=[0, 1])
df = df.drop(df.columns[20:], axis=1)

# Create a column combining the observation date and time
date = df.index.get_level_values(1)
time = df[("Observation", "Time")]
date_np = date.to_numpy(dtype='datetime64[ns]')
time_np = time.to_numpy()  # dtype=object of datetime.time
sec = np.array([t.hour * 3600 + t.minute * 60 + t.second for t in time_np],
               dtype='int64')
date_time = date_np + sec.astype('timedelta64[s]')  # datetime64 result

loc = df.columns.get_loc(("Observation", "Time"))

df.insert(loc + 1,
          column=("Observation", "Date & Time"),
          value=date_time)

df
# Out:
# Star                                                 Peak                      \
# Name                                             Altitude Distance        Lat
# Pikes Peak        2025-01-27 39 Aquarii              4300    50700  38.840278
#                              HD 217533               4300    50700  38.840278
#                   2025-01-30 39 Aquarii              4300    50700  38.840278
#                              HD 211410               4300    50700  38.840278
#                              HD 217429               4300    50700  38.840278
#                              HD 217721               4300    50700  38.840278
#                              HD 221665               4300    50700  38.840278
#                              Omega¹ Aquarii          4300    50700  38.840278
#                              HD 223559               4300    50700  38.840278
#                              HD 223774               4300    50700  38.840278
# ...

# %% [markdown]
# ### Result 1: For a given peak and date, occultation time of a star varies linearly as the star's right ascension, with a reciprocal slope of 15.04°/hour
#
# A plot of occultation time (hours) vs. the (catalogued) right ascension (°) should give a straight line for each peak-date pair. The reciprocal of the slope of each line should nearly equal Earth's rotation rate of 15.04°/hour. We observe this trend for every star analyzed.

# %%
# Plot right ascension vs. setting time, group by observation date
fig, ax = plt.subplots(figsize=(10, 10))
pk_dt = -1  # counter
m_inv_list = []  # list of reciprocal slopes
for (peak, date), subdf in df.groupby(level=(0, 1)):
    if len(subdf) >= 2:  # need 2 or more points for a line
        pk_dt += 1
        color = get_color(pk_dt)

        date_str = date.strftime('%b %d')
        t0 = pd.Timestamp(date)
        delta_t = df.xs((peak, date),
                        level=(0, 1))[("Observation", "Date & Time")] - t0
        hours = delta_t.dt.total_seconds() / 3600

        if hours.max() - hours.min() > 4 / 60:  # check for at least 4 min range
            ra = df.xs((peak, date), level=(0, 1))[('Star', 'RAα')]
            match (peak, date_str):  # use: angle ± 360° = same angle
                case ('Blodgett Peak', 'Feb 07'):
                    ra['LP Aquarii'] -= 360
                    ra['HD 216718'] -= 360
                case ('Pikes Peak', 'Jan 30'):
                    ra['HD 2345'] += 360

            m, b = np.polyfit(ra, hours, 1)  # best-fit line
            ra_fit = np.linspace(ra.min(), ra.max(), 100)
            hours_fit = m * ra_fit + b
            m_inv = 1 / m
            m_inv_list.append(m_inv)
            ax.plot(ra_fit, hours_fit, color=color, lw=1)

            ax.plot(ra, hours, ls='none',
                    marker='*', markersize=12, alpha=0.5,
                    mfc=color, mec='#000000', mew=0.5,
                    label=f"{peak} ({date_str}), {m_inv:.2f}°/hour")  # points

            stars = subdf.index.get_level_values(2)
            count = -1
            for xx, yy, star in zip(ra, hours, stars):
                count += 1
                if np.mod(count, 2) == 1:
                    x_disp = -3
                    y_disp = 0
                    ha = 'right'
                else:
                    x_disp = 3
                    y_disp = 0
                    ha = 'left'
                ax.text(xx + x_disp, yy + y_disp,
                        star,
                        fontsize=10,
                        color=color,
                        ha=ha)  # point labels (star names)

ax.plot([], [], '', color='none', label=' ')
ax.plot([], [],
        marker=r'$/$',
        color='black',
        ls='none',
        label=(
            f"mean reciprocal slope: {np.mean(m_inv_list):.2f}±"
            f"{np.std(m_inv_list):.2f} °/hour"
        ))
ax.legend(fontsize=12)
ax.xaxis.set_major_locator(MultipleLocator(60))
ax.yaxis.set_major_locator(MultipleLocator(1))
ax.grid(True, alpha=0.4)
plt.xlabel("Cataloged right ascension (°)", fontsize=14)
plt.ylabel("Occultation time (hours since midnight)", fontsize=14)
plt.savefig('right_ascension.jpg', dpi=1200, bbox_inches='tight')
plt.savefig('right_ascension.svg', bbox_inches='tight')

# %% [markdown]
# ### Result 2: For a given peak and star, occultation time drifts linearly with observation date, with a slope of 3m:56s/day
#
# A plot of occultation time (hours) vs. date should give a straight line for each peak-star pair. The slope of each line should nearly equal 3m:56s/day. This number is the daily stellar drift due to Earth's orbit around the Sun, and equals the ratio of the two fundamental periods of Earth---its rotation period (1 day) and its revolution period (1 year). We observe this almost exactly and uniformly for all stars.

# %%
# Plot setting time vs. date, group by star
fig, ax = plt.subplots(figsize=(10, 10))
pk_st = -1  # counter
m_list = []  # list of reciprocal slopes
for (peak, star), subdf in df.groupby(level=(0, 2)):
    if len(subdf) >= 2:  # need 2 or more points for a line
        pk_st += 1
        color = get_color(pk_st)

        t0 = pd.Timestamp('Dec 31 2024')
        delta_t = df.xs((peak, star),
                        level=(0, 2))[("Observation", "Date & Time")] - t0
        days = delta_t.dt.total_seconds() / 3600 / 24
        days_frac = np.mod(days, 1)
        days_int = days - days_frac
        hours = days_frac * 24

        m, b = np.polyfit(days_int, hours, 1)  # best-fit line
        days_int_fit = np.linspace(days_int.min(), days_int.max(), 200)
        hours_fit = m * days_int_fit + b
        m_list.append(m * 60)
        ax.plot(days_int_fit, hours_fit, color=color, lw=1)

        ax.plot(days_int, hours, ls='none',
                marker='*', markersize=12, alpha=0.5,
                mfc=color, mec='#000000', mew=0.5,
                label=f"{peak}/{star}, {min_sec(m * 60)}/day")  # points

        dates = subdf.index.get_level_values(1)
        stars = subdf.index.get_level_values(2)
        for xx, yy, date, star in zip(days_int, hours, dates, stars):
            if xx < 29:
                ha = 'left'
                va = 'bottom'
            else:
                ha = 'right'
                va = 'top'
            ax.text(xx, yy,
                    f"{star} ({date.strftime('%b %d')})",
                    fontsize=10,
                    color=color,
                    ha=ha, va=va)  # point labels (star names)

ax.plot([], [], '', color='none', label=' ')
ax.plot([], [],
        marker=r'$\backslash$',
        color='black',
        ls='none',
        label=(
            f"mean slope: ({min_sec(np.mean(m_list))} ± "
            f"{min_sec(np.std(m_list))})/day"
        ))
ax.legend(fontsize=12)
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_major_locator(MultipleLocator(0.2))
ax.grid(True, alpha=0.4)
plt.xlabel("Days since Dec 31, 2024", fontsize=14)
plt.ylabel("Occultation time (hours since midnight)", fontsize=14)
plt.savefig('daily_drift.jpg', dpi=1200, bbox_inches='tight')
plt.savefig('daily_drift.svg', bbox_inches='tight')

# %% [markdown]
# ### Result 3a: For a given observation site, all stars occulted by a peak have the same declination
#
# For a given observer location and peak, all obscured stars have very nearly the same declination. We see this clearly throughout the dataset.

# %%
# Plot declination vs. right ascension and group by peak
fig, ax = plt.subplots(figsize=(10, 10))
pk = -1  # counter

for peak in df.index.get_level_values(0).unique():
    pk += 1
    color = get_color(pk)

    dec = df.loc[peak, ("Star", "DEC")]
    ra = df.loc[peak, ("Star", "RAα")]
    mean = np.mean(dec)
    std = np.std(dec)
    num = len(dec)
    dec_range = dec.max() - dec.min()
    ra_range = ra.max() - ra.min()

    ax.plot(dec, ra,
            marker='*',
            markersize=12,
            ls='none',
            mfc=color,
            mec='#000000',
            mew=0.5,
            alpha=0.5)

    ax.plot([mean, mean], [ra.min(), ra.max()],
            ls='dashed', lw=1, color=color)

    match peak:  # choose label orientation
        case 'Cheyenne Mountain' | 'Blue Mountain':
            xx = dec.min() - 2 * dec_range
            yy = ra.min()
            ha = 'right'
        case 'Green Mountain' | 'North Peak':
            xx = dec.max() + 2 * dec_range
            yy = ra.max()
            ha = 'left'
        case _:
            xx = dec.max() + 2 * dec_range
            yy = ra.min()
            ha = 'left'

    ax.text(xx, yy,
            f"{peak}\n{num} occultations\ndeclination:\n{mean:.2f}°±{std:.2f}°",
            fontsize=10,
            color=color,
            ha=ha,
            va='center')  # first label

    match peak:  # choose label orientation
        case 'Pikes Peak' | 'Blodgett Peak':
            second_label = True
            xx = dec.min() - 2 * dec_range
            yy = ra.max()
            ha = 'right'
        case _:
            second_label = False

    if second_label:
        ax.text(xx, yy,
                (
                    f"{peak}\n{num} occultations\ndeclination:\n"
                    f"{mean:.2f}°±{std:.2f}°"
                ),
                fontsize=10,
                color=color,
                ha=ha,
                va='center')  # second label

plt.xlabel("Cataloged declination (°)", fontsize=14)
plt.ylabel("Cataloged right ascension (°)", fontsize=14)
ax.set_xlim(-50, 5)
ax.xaxis.set_major_locator(MultipleLocator(10))
ax.yaxis.set_major_locator(MultipleLocator(50))
ax.grid(True, alpha=0.4)
plt.savefig('declination.jpg', dpi=1200, bbox_inches='tight')
plt.savefig('declination.svg', bbox_inches='tight')

# %% [markdown]
# ### Result 3b: For a given observation site, the declination of the stars occulted by each peak can be calculated using globe geometry
#
# The (nearly identical) declination of the stars occulted by a peak as seen from a given observation site can be predicted by using globe geometry. This prediction uses the observer's and peak's coordinates to compute the elevation and azimuth of the peak from the observer, and then computes the declination from these angles, as described below. We see that this prediction closely matches the cataloged declination throughout the dataset.
#
# ### Equations for predicting declination of stars occulted by a peak for a given observer location
#
# For an observer located at coordinates (latitude $\phi_{ob}$, longitude $\lambda_{ob}$) and a peak located at (latitude $\phi_{pk}$, longitude $\lambda_{pk}$), the central angle $\theta$ between the observer and the peak is given by:
#
# $$\boxed{
# \cos \theta = \sin(\phi_{ob}) \sin(\phi_{pk}) +
# \cos(\phi_{ob}) \cos(\phi_{pk}) \cos(\lambda_{pk} - \lambda_{ob})
# }
# $$
#
# A straightforward way of deriving $\theta$ is to use an Earth-centric, Earth-fixed reference frame, take the dot product of the observer's position vector $\mathbf{r_{ob}}$ and the peak's position vector $\mathbf{r_{pk}}$ and divide the dot product $\mathbf{r_{ob} \cdot r_{pk}}$ by $(R+h) (R+H)$, where $R$ is Earth's radius, $h$ is the peak altitude and $H$ is the observer altitude (both measured above sea level).
#
# The elevation angle of the peak as seen by the observer, $e_{pk}$, is given by:
#
# $$\boxed{
# \sin (e_{pk}) =
# \frac{(R+h) \cos \theta - (R + H)}
# {\sqrt{(R+h)^2 + (R+H)^2 - 2 (R+h) (R+H) \cos \theta}}
# }
# $$
#
# This relationship can be derived by realizing that the altitude of the peak above the observer's horizontal is $(R+h) \cos \theta - R$ and the sine of $e_{pk}$ is the ratio of this altitude to the line-of-sight distance between the observer and the peak. The line of sight is given by the vector $\mathbf{v_{los}} = \mathbf{r_{pk} - r_{ob}}$, and its magnitude can be evaluated by $|\mathbf{v_{los}}| = \sqrt{\mathbf{v_{los} \cdot v_{los}}}$.
#
# To get the azimuth of the peak from the observer, we define local east-north-up (ENU) unit vectors $\mathbf{\hat{e}}$, $\mathbf{\hat{n}}$ and $\mathbf{\hat{u}}$ at the observer, which are mutually orthogonal:
#
# $$
# \mathbf{\hat e} =
# \begin{bmatrix}
# -\sin \lambda_{ob}\\
# \cos \lambda_{ob}\\
# 0
# \end{bmatrix}
# \qquad
# \mathbf{\hat n} =
# \begin{bmatrix}
# -\sin \phi_{ob} \cos \lambda_{ob}\\
# -\sin \phi_{ob} \sin \lambda_{ob}\\
# \cos \phi_{ob}
# \end{bmatrix}
# \qquad
# \mathbf{\hat u} =
# \begin{bmatrix}
# \cos \phi_{ob} \cos \lambda_{ob}\\
# \cos \phi_{ob} \sin \lambda_{ob}\\
# \sin \phi_{ob}
# \end{bmatrix}
# $$
#
# On projecting the unit line-of-sight vector $\mathbf{v_{los}}/|\mathbf{v_{los}}|$ to the unit vectors along north ($\mathbf{\hat n}$) and east ($\mathbf{\hat e}$) and taking the arctangent of their ratio, we get the azimuth of the peak. $A_{pk}$:
#
# $$
# A_{pk} = \tan^{-1}
# \left (
# \frac
# {\mathbf{v_{los}}/|\mathbf{v_{los}}| \cdot \mathbf{\hat e}}
# {\mathbf{v_{los}}/|\mathbf{v_{los}}| \cdot \mathbf{\hat n}}
# \right )
# $$
#
# On simplifying and determining the quadrant appropriately, we get:
#
# $$
# \boxed{
# A_{pk} = \tan^{-1}
# \left (
# \frac
# {\sin(\lambda_{pk}-\lambda_{ob}) \cos\phi_{pk}}
# {\cos\phi_{ob} \sin\phi_{pk} -
# \sin\phi_{ob}\,\cos\phi_{pk}\,\cos(\lambda_{pk}-\lambda_{ob})}
# \right )
# }
# $$
#
# The line-of-sight unit vector in ENU coordinates is:
#
# $$
# \mathbf{\hat s}_{\rm ENU} =
# \begin{bmatrix}
# \cos e_{\rm pk}\,\sin A_{\rm pk} \\
# \cos e_{\rm pk}\,\cos A_{\rm pk} \\
# \sin e_{\rm pk}
# \end{bmatrix}
# $$
#
# This can be transformed to the ECEF system to get the declination $\delta$ of the star:
#
# $$
# \boxed{
# \sin\delta =
# \sin\phi_{ob}\,\sin e_{\rm pk} +
# \cos\phi_{ob}\,\cos e_{\rm pk}\,\cos A_{\rm pk}
# }
# $$

# %%
# Plot estimated declination vs. actual declination
fig, ax = plt.subplots(figsize=(10, 10))
pk = -1  # counter

for peak in df.index.get_level_values(0).unique():
    pk += 1
    color = get_color(pk)

    dec = df.loc[peak, ("Star", "DEC")]
    mean = np.mean(dec)
    std = np.std(dec)
    num = len(dec)
    dec_range = dec.max() - dec.min()

    phi_ob = df.loc[peak, ("Observer", "Lat")] / 180 * np.pi
    lambda_ob = df.loc[peak, ("Observer", "Lon")] / 180 * np.pi
    phi_pk = df.loc[peak, ("Peak", "Lat")] / 180 * np.pi
    lambda_pk = df.loc[peak, ("Peak", "Lon")] / 180 * np.pi
    R = 6371000  # m
    h = df.loc[peak, ("Peak", "Altitude")]  # m
    H = df.loc[peak, ("Observer", "Altitude")]  # m

    theta = np.arccos(
        np.sin(phi_ob) * np.sin(phi_pk) +
        np.cos(phi_ob) * np.cos(phi_pk) * np.cos(lambda_pk - lambda_ob)
    )

    sin_e_peak = (
        ((R + h) * np.cos(theta) - (R + H)) /
        np.sqrt((R + h)**2 + (R + H)**2 - 2 * (R + h) * (R + H) * np.cos(theta))
    )
    sin_e_peak = np.clip(sin_e_peak, -1.0, 1.0)
    e_peak = np.arcsin(sin_e_peak)

    A_peak = np.atan2(
        np.sin(lambda_pk - lambda_ob) * np.cos(phi_pk),
        (
            np.cos(phi_ob) * np.sin(phi_pk) -
            np.sin(phi_ob) * np.cos(phi_pk) * np.cos(lambda_pk - lambda_ob)
        )
    )

    dec_est = np.arcsin(
        np.sin(phi_ob) * sin_e_peak +
        np.cos(phi_ob) * np.cos(e_peak) * np.cos(A_peak)
    ) / np.pi * 180

    ax.plot(dec, dec_est,
            marker='*',
            markersize=12,
            ls='none',
            mfc=color,
            mec='#000000',
            mew=0.5,
            alpha=0.5)

    match peak:  # choose label orientation
        case (
            'Cheyenne Mountain' |
            'Pikes Peak' |
            'North Peak' |
            'Mount Rosa'
        ):
            xx = mean + 2 * dec_range
            yy = mean - 2 * dec_range
            ha = 'left'
            va = 'top'
        case 'Blodgett Peak' | 'Green Mountain':
            xx = mean - 2 * dec_range
            yy = mean + 2 * dec_range
            ha = 'right'
            va = 'bottom'
        case 'Blue Mountain':
            xx = mean - 2 * dec_range
            yy = mean - 2 * dec_range
            ha = 'right'
            va = 'top'
        case _:
            xx = mean + 2 * dec_range
            yy = mean + 2 * dec_range
            ha = 'left'
            va = 'bottom'

    ax.text(xx, yy,
            (
                f"{peak}\n({num} occultations)\ndeclination: "
                f"{mean:.2f}°±{std:.2f}°"
            ),
            fontsize=10,
            ha=ha, va=va,
            color=color)

m = 1
b = 0
dec_fit = np.linspace(-50, 0, 100)
dec_est_fit = m * dec_fit + b
ax.plot(dec_fit, dec_est_fit, color='black', lw=1)

plt.xlabel("Cataloged declination (°)", fontsize=14)
plt.ylabel(("Predicted declination from observer/peak " +
            "coordinates and globe geometry (°)"), fontsize=14)
ax.set_xlim(-55, 5)
ax.set_ylim(-55, 5)
ax.xaxis.set_major_locator(MultipleLocator(10))
ax.yaxis.set_major_locator(MultipleLocator(10))
ax.grid(True, alpha=0.4)
plt.savefig('declination_correlation.jpg', dpi=1200, bbox_inches='tight')
plt.savefig('declination_correlation.svg', bbox_inches='tight')

# %% [markdown]
# ### Result 3c: For a given observation site, we can use known data (declinations of the stars occulted by different peaks, observer elevation and peak elevations) to estimate the Earth's radius
#
# For a given observation site, the relationship between the star declination and peak height uses Earth's radius as a parameter. Thus, this relationship can be used to estimate the radius by fitting a radius that minimizes the sum-of-squared residuals. We see that this estimation gives a radius of 3,911 mile, which is impressively within 1.25% of the known average radius of 3,959 mile.

# %%
# Estimate radius from cataloged declination
def ssr(R, sigma_dec=0.25):
    scalar_input = np.isscalar(R)
    R = np.atleast_1d(np.asarray(R, dtype=float))
    ssr = np.zeros_like(R, dtype=float)

    for peak in df.index.get_level_values(0).unique():
        dec = df.loc[peak, ("Star", "DEC")].to_numpy(dtype=float)

        phi_ob = df.loc[peak, ("Observer", "Lat")].iloc[0] / 180 * np.pi
        lambda_ob = df.loc[peak, ("Observer", "Lon")].iloc[0] / 180 * np.pi
        phi_pk = df.loc[peak, ("Peak", "Lat")].iloc[0] / 180 * np.pi
        lambda_pk = df.loc[peak, ("Peak", "Lon")].iloc[0] / 180 * np.pi
        h = df.loc[peak, ("Peak", "Altitude")].iloc[0]  # m
        H = df.loc[peak, ("Observer", "Altitude")].iloc[0]  # m

        theta = np.arccos(
            np.sin(phi_ob) * np.sin(phi_pk) +
            np.cos(phi_ob) * np.cos(phi_pk) * np.cos(lambda_pk - lambda_ob)
        )

        sin_e_peak = (
            ((R + h) * np.cos(theta) - (R + H)) /
            np.sqrt((R + h)**2 + (R + H)**2 - 2 * (R + h) * (R + H) * np.cos(theta))
        )
        sin_e_peak = np.clip(sin_e_peak, -1.0, 1.0)
        e_peak = np.arcsin(sin_e_peak)

        A_peak = np.atan2(
            np.sin(lambda_pk - lambda_ob) * np.cos(phi_pk),
            (
                np.cos(phi_ob) * np.sin(phi_pk) -
                np.sin(phi_ob) * np.cos(phi_pk) * np.cos(lambda_pk - lambda_ob)
            )
        )

        dec_est = np.arcsin(
            np.sin(phi_ob) * sin_e_peak +
            np.cos(phi_ob) * np.cos(e_peak) * np.cos(A_peak)
        ) / np.pi * 180

        ssr += (
            ((dec[None, :] - dec_est[:, None])**2 /
             sigma_dec**2).sum(axis=1)
        )  # assuming SD of 15 arcminutes

    return ssr[0] if scalar_input else ssr


res = opt.minimize_scalar(ssr)

print('Estimated radius:\t\t',
      f'{res.x / 1000:.0f} km = {res.x / 1609.344:.0f} mile')
print('Sum of squared residuals:\t', f'{res.fun:.2f}')
# Out:
# Estimated radius:		 6295 km = 3911 mile
# Sum of squared residuals:	 16.77

# %%
fig, ax = plt.subplots(figsize=(10, 10))

radius_fit = np.linspace(2000, 20000, 100)  # R range in km
ssr_fit = ssr(radius_fit * 1000)

ax.plot(radius_fit, ssr_fit, color='r', ls='-')

ax.plot(res.x / 1000, res.fun,
        color='k', marker='o', mfc='black')
ax.text(res.x / 1000, res.fun + 100,
        (
            f"estimated radius: \n{res.x / 1000:,.0f} km\n" +
            f"= {res.x / 1609.344:,.0f} mile"
        ),
        ha='center', va='bottom')

plt.xlabel("R (km)", fontsize=14)
plt.ylabel("sum of squared residuals (SSR)", fontsize=14)

ax.set_xlim(2000, 20000)
ax.grid(True, alpha=0.4)

plt.savefig('estimated_radius.jpg', dpi=1200, bbox_inches='tight')
plt.savefig('estimated_radius.svg', bbox_inches='tight')
